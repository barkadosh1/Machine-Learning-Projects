# %%
import matplotlib.pyplot as plt

# %%
x = [499,999, 1498, 1999, 2499, 2998, 3499, 3999, 4499, 4998]
y = [0.012923,.009276, .007903, .007234, .006387, .005909, 0.005753, 0.005584, 0.005242, 0.005170]

# %%
plt.plot(x, y)
plt.title('Loss vs. Iteration at Learning Rate = 0.01')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.ylim(bottom=0.0, top=0.015)  
plt.show()
